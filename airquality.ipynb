# %%
# Install required packages (uncomment if running for the first time)
# %pip install pandas numpy matplotlib sodapy

# Standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sodapy import Socrata

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sodapy import Socrata

# %%
# Configuration
baseURL = 'data.cityofnewyork.us'
appToken = 'XQq7xwYF1urly2LSICI3Sis7Y'  # Shameel's app token
dataset_id = 'c3uy-2p5r'  # NYC Air Pollution dataset
timeout = 60
chunk = 5000  # Rows to pull

# Initialize Socrata connection
client = Socrata(baseURL, appToken, timeout=timeout)

# %%
# Fetch the air pollution data
print(f"Fetching {chunk} rows from dataset {dataset_id}...")
air_data = client.get(dataset_id, limit=chunk)

# Convert to DataFrame
df = pd.DataFrame(air_data)

# Display basic information
print(f"\nDataset shape: {df.shape}")
print(f"\nColumn names:")
print(df.columns.tolist())
# Out:
# Fetching 5000 rows from dataset c3uy-2p5r...
#
# Dataset shape: (5000, 11)
#
# Column names:
# ['unique_id', 'indicator_id', 'name', 'measure', 'measure_info', 'geo_type_name', 'geo_join_id', 'geo_place_name', 'time_period', 'start_date', 'data_value']

# %%
# Data exploration
print("\nFirst few rows:")
print(df.head())

print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isnull().sum())
# Out:
# First few rows:
#   unique_id indicator_id                     name measure measure_info  \
# 0    874915          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 1    878212          386               Ozone (O3)    Mean          ppb
# 2    874335          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 3    877170          375   Nitrogen dioxide (NO2)    Mean          ppb
# 4    874443          365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#   geo_type_name geo_join_id                      geo_place_name  time_period  \
# 0            CD         310  Bay Ridge and Dyker Heights (CD10)  Summer 2023
# 1         UHF42         408                             Jamaica  Summer 2023
# 2         UHF42         202          Downtown - Heights - Slope  Summer 2023
# 3            CD         303            Bedford Stuyvesant (CD3)  Summer 2023
# 4         UHF42         407                    Southwest Queens  Summer 2023
#
#                 start_date   data_value
# ...

# %%
# display the dataset - use DataFrame methods or the notebook's rich display

# show first few rows
df.head()

# to display all rows/columns (be careful on large datasets):
# display(df)

# or show a sample
# df.sample(10)
# Out:
#   unique_id indicator_id                     name measure measure_info  \
# 0    874915          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 1    878212          386               Ozone (O3)    Mean          ppb
# 2    874335          365  Fine particles (PM 2.5)    Mean       mcg/m3
# 3    877170          375   Nitrogen dioxide (NO2)    Mean          ppb
# 4    874443          365  Fine particles (PM 2.5)    Mean       mcg/m3
#
#   geo_type_name geo_join_id                      geo_place_name  time_period  \
# 0            CD         310  Bay Ridge and Dyker Heights (CD10)  Summer 2023
# 1         UHF42         408                             Jamaica  Summer 2023
# 2         UHF42         202          Downtown - Heights - Slope  Summer 2023
# 3            CD         303            Bedford Stuyvesant (CD3)  Summer 2023
# 4         UHF42         407                    Southwest Queens  Summer 2023
#
#                 start_date   data_value
# ...
